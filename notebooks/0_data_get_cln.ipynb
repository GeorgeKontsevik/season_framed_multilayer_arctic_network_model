# %% [markdown]
# fid	full_id	population	name	district	school	kindergarten	post	library	culture	atm	health	port	airport	shop	pristan	pvz	gas	mfc	geometry

# %%
from tqdm import tqdm
from cleanerreader import process_settlement_data

for service in tqdm(
    [
        # "school",
        # "kindergarten",
        # "post",
        # "library",
        # "culture",
        # "atm",
        # "health",
        # "port",
        # "airport",
        # "shop",
        "pristan",
        # "pvz",
        # "gas",
        # "mfc",
    ]
):
    # "mezen", "yakut_chuk", "yanao_kras"
    for settl in ["nao", "mezen", "yakut_chuk", "yanao_kras"]:
        process_settlement_data(
            service_amenities_count_column=service, settl_name=settl
        )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/test/Documents/code/iccs25/new_notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/new_notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/new_notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/new_notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# Строки с обратным порядком найдены:
#            name  population  marina                        geometry
# 38      Амдерма         444       1  POINT (1070458.851 766094.225)
# 13        Андег         175       1   POINT (834175.227 445156.698)
# 42  Архангельск        <NA>       1   POINT (360029.734 -40535.595)
# 25      Белушье          50       1    POINT (633349.599 272766.98)
# 17      Бугрино         416       0     POINT (651378.74 494278.85)
# Строк с обратным порядком не найдено.
#          name  population  marina                   geometry
# 36   Азаполье           9       1  POINT (45.17779 65.29261)
# 14  Баковская          33       0   POINT (46.38103 65.7242)
# 27   Березник         134       0   POINT (44.99312 65.4793)
# 46        Бор           0       0   POINT (44.38419 65.7135)
# 5       Бычье         146       0  POINT (45.05246 65.79109)
# Строк с обратным порядком не найдено.
#            name  population  marina                    geometry
# 18  Алеко-Кюель         512     0.0  POINT (151.87868 68.67876)
# 3    Андрюшкино         741     0.0    POINT (154.44885 69.172)
# 11       Анюйск         380     1.0  POINT (161.56043 68.34519)
# 14     Аргахтах         469     0.0  POINT (153.37696 68.44334)
# 19    Березовка         280     0.0  POINT (156.58522 67.12961)
# Строк с обратным порядком не найдено.
#           name  population  marina                   geometry
# 26   Антипаюта        2685     1.0  POINT (76.86735 69.09759)
# 22  Байкаловск         122     0.0  POINT (83.62348 70.69578)
# 1    Волочанка         530     0.0  POINT (94.53947 70.97695)
# 10   Воронцово         253     1.0   POINT (83.5584 71.69746)
# 27    Газ-Сале        1735     1.0  POINT (78.99184 67.36392)
