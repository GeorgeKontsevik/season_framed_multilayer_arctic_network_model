# %% [markdown]
# fid	full_id	population	name	district	school	kindergarten	post	library	culture	atm	health	port	airport	shop	pristan	pvz	gas	mfc	geometry

# %%
from tqdm import tqdm
from new_notebooks.cleanerreader import process_settlement_data

for service in tqdm(
    [
        "school",
        "kindergarten",
        "post",
        "library",
        "culture",
        "atm",
        "health",
        "port",
        "airport",
        "shop",
        "pristan",
        # "pvz",
        # "gas",
        # "mfc",
    ]
):
    for settl in ["mezen", "yakut_chuk", "yanao_kras"]:
        process_settlement_data(
            service_amenities_count_column=service, settl_name=settl
        )
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#   9%|▉         | 1/11 [00:00<00:01,  7.73it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  18%|█▊        | 2/11 [00:00<00:01,  8.06it/s]
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  27%|██▋       | 3/11 [00:00<00:00,  8.02it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
#  36%|███▋      | 4/11 [00:00<00:00,  7.72it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  45%|████▌     | 5/11 [00:00<00:00,  8.00it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  55%|█████▍    | 6/11 [00:00<00:00,  8.13it/s]
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  64%|██████▎   | 7/11 [00:00<00:00,  8.23it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  73%|███████▎  | 8/11 [00:00<00:00,  8.24it/s]
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  82%|████████▏ | 9/11 [00:01<00:00,  8.18it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
#  91%|█████████ | 10/11 [00:01<00:00,  7.68it/s]/Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# /Users/test/Documents/code/iccs25/notebooks/cleanerreader.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_time.fillna(0, inplace=True)
# 100%|██████████| 11/11 [00:01<00:00,  7.98it/s]
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
# Строк с обратным порядком не найдено.
